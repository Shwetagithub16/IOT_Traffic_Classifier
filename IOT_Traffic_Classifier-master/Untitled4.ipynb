# %%
#import tensorflow as tf
import os
import pandas as pd
from utils import *

# %%
data = pd.read_csv('../Data/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled.csv')

# %%
data = data.drop('Unnamed: 0',axis=1)
data
# Out:
#                 ts                 uid                  id.orig_h  id.orig_p  \
# 0     1.537523e+09   CJAF5z3MDFg4XVDXB                    0.0.0.0         68
# 1     1.537523e+09  CcYEFX3Qj9xdNX1ZCa                192.168.2.1       5353
# 2     1.537523e+09  CF6fCK1nFqvI1XxGM1  fe80::80e6:50ff:fe12:1464       5353
# 3     1.537523e+09  C2dlio3MkdwWJ80y04             169.254.15.115       5353
# 4     1.537523e+09  COrF0t2uLErai9nfH5                    0.0.0.0         68
# ...            ...                 ...                        ...        ...
# 1369  1.537543e+09  CrPQ4n1jVFxbm0mcj9             192.168.69.136      51443
# 1370  1.537543e+09  Ce0LkH33VlZBF8Vw93   fe80::106c:9e5b:3af8:9cf        143
# 1371  1.537543e+09  CdWSpn4EA2vXfUBqI7  fe80::183b:7564:dbcc:3eca        143
# 1372  1.537543e+09  ClKCqX3JOxjrti9lLh  fe80::1847:a1bd:8d13:f43c        143
# 1373  1.537543e+09  CDsdf81FPzUzFBBRBe   fe80::1c5c:213d:7cf8:890        143
#
# ...

# %%
data.dtypes
# Out:
# ts                float64
# uid                object
# id.orig_h          object
# id.orig_p           int64
# id.resp_h          object
# id.resp_p           int64
# proto              object
# service            object
# duration           object
# orig_bytes         object
# resp_bytes         object
# conn_state         object
# local_orig         object
# local_resp         object
# missed_bytes        int64
# history            object
# orig_pkts           int64
# orig_ip_bytes       int64
# resp_pkts           int64
# resp_ip_bytes       int64
# tunnel_parents     object
# label              object
# detailed-label     object
# dtype: object

# %%
data.nunique()
# Out:
# ts                1374
# uid               1374
# id.orig_h           24
# id.orig_p          770
# id.resp_h          136
# id.resp_p           12
# proto                3
# service              5
# duration          1069
# orig_bytes         163
# resp_bytes          79
# conn_state          10
# local_orig           1
# local_resp           1
# missed_bytes         1
# history             34
# orig_pkts           47
# orig_ip_bytes      226
# resp_pkts           36
# resp_ip_bytes      102
# tunnel_parents       1
# label                1
# detailed-label       1
# dtype: int64

# %%
for column in data.columns:
    print(column, data[column].unique())
# Out:
# ts [1.53752282e+09 1.53752290e+09 1.53752290e+09 ... 1.53754254e+09
#  1.53754250e+09 1.53754257e+09]
# uid ['CJAF5z3MDFg4XVDXB' 'CcYEFX3Qj9xdNX1ZCa' 'CF6fCK1nFqvI1XxGM1' ...
#  'CdWSpn4EA2vXfUBqI7' 'ClKCqX3JOxjrti9lLh' 'CDsdf81FPzUzFBBRBe']
# id.orig_h ['0.0.0.0' '192.168.2.1' 'fe80::80e6:50ff:fe12:1464' '169.254.15.115'
#  '192.168.2.3' 'fe80::4eef:c0ff:fe27:561e' '::' 'fe80::482:6d20:b3e:adf4'
#  '192.168.69.192' 'fe80::82e6:50ff:fe21:867c' '192.168.69.129'
#  'fe80::1060:27a7:f64c:dec9' 'fe80::1847:a1bd:8d13:f43c' '192.168.69.73'
#  'fe80::ad:a9ad:1b82:2e67' 'fe80::14c5:8f26:563a:f0cb' '192.168.69.17'
#  '192.168.69.136' 'fe80::106c:9e5b:3af8:9cf' '192.168.69.200'
#  'fe80::183b:7564:dbcc:3eca' '192.168.69.178' '192.168.69.241'
#  'fe80::1c5c:213d:7cf8:890']
# id.orig_p [   68  5353 43216 40621 40623 40624 59744 55971 41548 33413 54908  1112
#  16356  1255 12231 39474 57819 60048 43654 10862 42964 31664 60994  7587
# ...

# %%
path = '../Data/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/'

# %%
dirs = os.listdir('../Data/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/')

# %%
for direct in dirs:
    print(direct, os.listdir(path + direct))
# Out:
# CTU-Honeypot-Capture-4-1 ['bro']
# CTU-Honeypot-Capture-5-1 ['bro']
# CTU-Honeypot-Capture-7-1 ['Somfy-01']
# CTU-IoT-Malware-Capture-1-1 ['bro']
# CTU-IoT-Malware-Capture-17-1 ['bro']
# CTU-IoT-Malware-Capture-20-1 ['bro']
# CTU-IoT-Malware-Capture-21-1 ['bro']
# CTU-IoT-Malware-Capture-3-1 ['bro']
# CTU-IoT-Malware-Capture-33-1 ['bro']
# CTU-IoT-Malware-Capture-34-1 ['bro']
# CTU-IoT-Malware-Capture-35-1 ['bro']
# CTU-IoT-Malware-Capture-36-1 ['bro']
# CTU-IoT-Malware-Capture-39-1 ['bro']
# CTU-IoT-Malware-Capture-42-1 ['bro']
# CTU-IoT-Malware-Capture-43-1 ['bro']
# CTU-IoT-Malware-Capture-44-1 ['bro']
# CTU-IoT-Malware-Capture-48-1 ['bro']
# CTU-IoT-Malware-Capture-49-1 ['bro']
# CTU-IoT-Malware-Capture-52-1 ['bro']
# CTU-IoT-Malware-Capture-60-1 ['bro']
# CTU-IoT-Malware-Capture-7-1 ['bro']
# CTU-IoT-Malware-Capture-8-1 ['bro']
# CTU-IoT-Malware-Capture-9-1 ['bro']

# %%
def return_final_folder(path):
    while os.path.isdir(path):
        path = path + '/' +  os.listdir(path)[0]
    return path

all_files_path = []
for folder in os.listdir(path):
    subpath = path + '/' + folder
    # print(return_final_folder(subpath))
    all_files_path.append(return_final_folder(subpath))

# %%
all_files_path
# Out:
# ['../Data/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios//CTU-Honeypot-Capture-4-1/bro/conn.log.labeled',
#  '../Data/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios//CTU-Honeypot-Capture-5-1/bro/conn.log.labeled',
#  '../Data/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios//CTU-Honeypot-Capture-7-1/Somfy-01/bro/conn.log.labeled',
#  '../Data/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios//CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled',
#  '../Data/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios//CTU-IoT-Malware-Capture-17-1/bro/conn.log.labeled',
#  '../Data/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios//CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled',
#  '../Data/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios//CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled',
# ...

# %%
data2 = ZeekLogs_to_csv(all_files_path[0])

# %%
data2
# Out:
#      Unnamed: 0            ts                 uid      id.orig_h  id.orig_p  \
# 0             0  1.540469e+09  CGm6jB4dXK71ZDWUDh  192.168.1.132      58687
# 1             1  1.540469e+09  CnaDAG3n5r8eiG4su2  192.168.1.132       1900
# 2             2  1.540469e+09  CUrxU238nt0m6yTgKf  192.168.1.132      32893
# 3             3  1.540470e+09  CGQf8t1kjdxB5PHXL4  192.168.1.132      53395
# 4             4  1.540470e+09  CUo9DH2QDnCaBIGjkg  192.168.1.132      52801
# ..          ...           ...                 ...            ...        ...
# 447         447  1.540547e+09  CaITg437HfJAXTXZ44  192.168.1.132      53722
# 448         448  1.540547e+09  ChD10Y1fVGrFvMpD6g  192.168.1.132      43799
# 449         449  1.540548e+09  Caxyou4MZpRXfDBG8h  192.168.1.132      51285
# 450         450  1.540469e+09   CkHQfG3B034MyvP3W  192.168.1.132      37653
# 451         451  1.540478e+09  ClZeN63S7LbgEs2ZNk  192.168.1.132       1900
#
# ...

# %%
pd.concat([data,data2],ignore_index=True)
# Out:
#                 ts                 uid                  id.orig_h  id.orig_p  \
# 0     1.537523e+09   CJAF5z3MDFg4XVDXB                    0.0.0.0         68
# 1     1.537523e+09  CcYEFX3Qj9xdNX1ZCa                192.168.2.1       5353
# 2     1.537523e+09  CF6fCK1nFqvI1XxGM1  fe80::80e6:50ff:fe12:1464       5353
# 3     1.537523e+09  C2dlio3MkdwWJ80y04             169.254.15.115       5353
# 4     1.537523e+09  COrF0t2uLErai9nfH5                    0.0.0.0         68
# ...            ...                 ...                        ...        ...
# 1821  1.540547e+09  CaITg437HfJAXTXZ44              192.168.1.132      53722
# 1822  1.540547e+09  ChD10Y1fVGrFvMpD6g              192.168.1.132      43799
# 1823  1.540548e+09  Caxyou4MZpRXfDBG8h              192.168.1.132      51285
# 1824  1.540469e+09   CkHQfG3B034MyvP3W              192.168.1.132      37653
# 1825  1.540478e+09  ClZeN63S7LbgEs2ZNk              192.168.1.132       1900
#
# ...
